# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

query_url = f"{url}appid={weather_api_key}&units={units}&q="

# %%
City = []
cloudiness = []
country = []
date = []
humidity = []
lat = []
lng = []
maxtemp = []
windspeed = []

# %%
for city in cities:
    try:
        response = requests.get(query_url + city).json()
        City.append(response["name"])
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        humidity.append(response["main"]["humidity"])
        lat.append(response["coord"]["lat"])
        lng.append(response["coord"]["lon"])
        maxtemp.append(response["main"]["temp_max"])
        windspeed.append(response["wind"]["speed"])
        number_cities = len(City)
        print(f'City Number {number_cities}, {city}')
    except KeyError:
        print(f'HEY! {city} does not exist')
# Out:
# City Number 1, ushuaia
# City Number 2, airai
# City Number 3, hilo
# City Number 4, yangambi
# City Number 5, punta arenas
# City Number 6, moron
# City Number 7, albany
# City Number 8, tabas
# City Number 9, barrow
# City Number 10, busselton
# City Number 11, arak
# City Number 12, hobart
# City Number 13, kautokeino
# City Number 14, avarua
# City Number 15, puerto ayora
# City Number 16, murgab
# HEY! grand river south east does not exist
# City Number 17, lompoc
# City Number 18, kodiak
# City Number 19, kaitangata
# City Number 20, mahebourg
# City Number 21, yellowknife
# City Number 22, bengkulu
# City Number 23, port alfred
# City Number 24, muncar
# City Number 25, abu samrah
# City Number 26, luderitz
# HEY! barentsburg does not exist
# City Number 27, kruisfontein
# City Number 28, khromtau
# City Number 29, mega
# City Number 30, iracoubo
# City Number 31, nikolskoye
# City Number 32, hithadhoo
# City Number 33, la ronge
# City Number 34, qaanaaq
# City Number 35, pisco
# City Number 36, mataura
# City Number 37, pochutla
# City Number 38, bethel
# City Number 39, cabo san lucas
# City Number 40, hermanus
# HEY! rungata does not exist
# HEY! attawapiskat does not exist
# City Number 41, pangnirtung
# City Number 42, mar del plata
# City Number 43, jamestown
# City Number 44, rikitea
# City Number 45, longyearbyen
# City Number 46, chuy
# City Number 47, provideniya
# City Number 48, arraial do cabo
# City Number 49, conceicao do araguaia
# City Number 50, marystown
# City Number 51, laguna
# HEY! illoqqortoormiut does not exist
# City Number 52, san policarpo
# City Number 53, rawson
# City Number 54, lata
# City Number 55, mirabad
# City Number 56, saint-philippe
# City Number 57, kahului
# City Number 58, yarada
# City Number 59, port elizabeth
# City Number 60, chipurupalle
# City Number 61, suntar
# City Number 62, balikpapan
# City Number 63, port blair
# City Number 64, atuona
# City Number 65, vaini
# City Number 66, castro
# City Number 67, pevek
# City Number 68, buala
# City Number 69, warmbad
# City Number 70, chilca
# City Number 71, akyab
# City Number 72, richards bay
# City Number 73, chapleau
# City Number 74, byron bay
# City Number 75, esperance
# City Number 76, benicarlo
# City Number 77, voskresenskoye
# City Number 78, kuhdasht
# City Number 79, kapaa
# City Number 80, kavieng
# City Number 81, upernavik
# City Number 82, avanigadda
# HEY! saryshagan does not exist
# HEY! taolanaro does not exist
# City Number 83, taicheng
# City Number 84, cidreira
# City Number 85, yar-sale
# City Number 86, berlevag
# City Number 87, butaritari
# City Number 88, ihosy
# City Number 89, trat
# HEY! cheuskiny does not exist
# City Number 90, geraldton
# City Number 91, hambantota
# City Number 92, gravdal
# City Number 93, tuktoyaktuk
# City Number 94, fortuna
# HEY! mys shmidta does not exist
# City Number 95, tarija
# City Number 96, carnarvon
# City Number 97, katsuura
# City Number 98, moses lake
# City Number 99, new norfolk
# City Number 100, deputatskiy
# City Number 101, oeiras
# City Number 102, ko samui
# City Number 103, curuca
# City Number 104, kizilskoye
# City Number 105, alice springs
# City Number 106, omboue
# City Number 107, khatanga
# City Number 108, alofi
# City Number 109, roald
# City Number 110, ngunguru
# City Number 111, tadine
# City Number 112, faanui
# City Number 113, palaia fokaia
# City Number 114, bathsheba
# City Number 115, porto novo
# City Number 116, sakaiminato
# City Number 117, san giovanni in fiore
# City Number 118, aklavik
# City Number 119, victoria
# City Number 120, lebu
# City Number 121, batagay-alyta
# City Number 122, vila franca do campo
# City Number 123, miles city
# City Number 124, chokurdakh
# City Number 125, saint george
# City Number 126, seydi
# City Number 127, ternate
# City Number 128, dawei
# HEY! vaitupu does not exist
# City Number 129, clyde river
# HEY! bolungarvik does not exist
# City Number 130, yerbogachen
# City Number 131, mantena
# City Number 132, saint anthony
# City Number 133, sambava
# City Number 134, tres picos
# City Number 135, hokitika
# City Number 136, aasiaat
# City Number 137, la rioja
# City Number 138, salaga
# HEY! zanatepec does not exist
# City Number 139, thinadhoo
# City Number 140, georgetown
# City Number 141, sandwick
# City Number 142, grindavik
# City Number 143, patuli
# City Number 144, turukhansk
# City Number 145, keti bandar
# City Number 146, vao
# City Number 147, ranong
# City Number 148, spornoye
# City Number 149, yulara
# City Number 150, seoul
# City Number 151, lagoa
# City Number 152, boa vista
# City Number 153, preeceville
# City Number 154, itoman
# City Number 155, freeport
# City Number 156, toora-khem
# City Number 157, liancheng
# City Number 158, saldanha
# City Number 159, saskylakh
# HEY! nizhneyansk does not exist
# City Number 160, bronnoysund
# City Number 161, kloulklubed
# City Number 162, east london
# City Number 163, klaksvik
# City Number 164, bluff
# City Number 165, tual
# HEY! belushya guba does not exist
# City Number 166, paita
# City Number 167, raudeberg
# City Number 168, singaparna
# City Number 169, dingle
# City Number 170, ust-barguzin
# City Number 171, mombasa
# City Number 172, tasiilaq
# City Number 173, bambous virieux
# City Number 174, thompson
# City Number 175, san luis
# City Number 176, santa maria
# City Number 177, slave lake
# City Number 178, kalmunai
# HEY! tsihombe does not exist
# City Number 179, kommunisticheskiy
# City Number 180, mikuni
# City Number 181, belgrade
# City Number 182, kernersville
# City Number 183, wattegama
# City Number 184, ribeira grande
# City Number 185, pudozh
# City Number 186, pangody
# City Number 187, archidona
# City Number 188, bac lieu
# City Number 189, lahaina
# HEY! khormuj does not exist
# City Number 190, rafai
# City Number 191, voznesenye
# City Number 192, songea
# HEY! aflu does not exist
# City Number 193, gap
# City Number 194, kilindoni
# City Number 195, calvinia
# City Number 196, weligama
# City Number 197, souillac
# HEY! sentyabrskiy does not exist
# City Number 198, ndende
# City Number 199, rayong
# HEY! paradwip does not exist
# City Number 200, san cristobal
# City Number 201, daraitan
# City Number 202, rio grande
# City Number 203, ponta do sol
# City Number 204, lima
# City Number 205, maxixe
# City Number 206, tanout
# City Number 207, juneau
# City Number 208, namibe
# City Number 209, ballina
# City Number 210, letlhakeng
# City Number 211, severo-kurilsk
# City Number 212, mandiana
# City Number 213, kiama
# City Number 214, korla
# City Number 215, cape town
# City Number 216, vardo
# City Number 217, popondetta
# City Number 218, dikson
# City Number 219, pacifica
# City Number 220, biak
# City Number 221, pemberton
# City Number 222, acapulco
# City Number 223, marawi
# City Number 224, dafeng
# City Number 225, osmena
# City Number 226, sitka
# City Number 227, quatre cocos
# City Number 228, kamaishi
# City Number 229, champerico
# HEY! samusu does not exist
# City Number 230, san patricio
# City Number 231, hasaki
# City Number 232, bocas del toro
# City Number 233, gushikawa
# City Number 234, palauig
# City Number 235, katangli
# City Number 236, nakonde
# City Number 237, progreso
# City Number 238, marshfield
# City Number 239, sept-iles
# City Number 240, borogontsy
# City Number 241, pelym
# City Number 242, palmer
# City Number 243, coquimbo
# City Number 244, chicama
# City Number 245, hovd
# City Number 246, russell
# City Number 247, kamenka
# City Number 248, los llanos de aridane
# City Number 249, tuatapere
# City Number 250, cherskiy
# City Number 251, kikwit
# City Number 252, great malvern
# City Number 253, meulaboh
# City Number 254, xuanhua
# HEY! tumannyy does not exist
# City Number 255, paysandu
# City Number 256, sungai padi
# City Number 257, vestmannaeyjar
# City Number 258, muros
# City Number 259, kapuskasing
# City Number 260, gallup
# City Number 261, artesia
# City Number 262, ouargaye
# City Number 263, kuloy
# City Number 264, shar
# City Number 265, axim
# City Number 266, neuquen
# City Number 267, lorengau
# City Number 268, ust-nera
# City Number 269, iqaluit
# City Number 270, soyaux
# City Number 271, bako
# City Number 272, mangrol
# City Number 273, port hedland
# City Number 274, tezu
# City Number 275, bredasdorp
# City Number 276, khuzhir
# City Number 277, margate
# City Number 278, nagornyy
# City Number 279, gat
# City Number 280, samandag
# City Number 281, san angelo
# City Number 282, nishihara
# HEY! amderma does not exist
# City Number 283, lannion
# City Number 284, okahandja
# City Number 285, puerto escondido
# City Number 286, narsaq
# City Number 287, bekwai
# City Number 288, tautira
# City Number 289, husavik
# HEY! bandar-e torkaman does not exist
# City Number 290, santo domingo
# City Number 291, khani
# City Number 292, sorland
# City Number 293, fairbanks
# City Number 294, sao filipe
# City Number 295, yeroham
# HEY! viligili does not exist
# City Number 296, nanortalik
# City Number 297, cunha
# City Number 298, hamilton
# City Number 299, san quintin
# City Number 300, diamantino
# City Number 301, kampong chhnang
# City Number 302, lashio
# City Number 303, altay
# HEY! ust-kamchatsk does not exist
# City Number 304, lisakovsk
# City Number 305, road town
# City Number 306, farmington
# City Number 307, ismailia
# City Number 308, fort-shevchenko
# HEY! hihifo does not exist
# City Number 309, coxim
# City Number 310, combs-la-ville
# City Number 311, kutum
# City Number 312, nizhniy tsasuchey
# City Number 313, bandar-e anzali
# City Number 314, shelburne
# City Number 315, owatonna
# HEY! warqla does not exist
# City Number 316, alberton
# City Number 317, tura
# HEY! bacuit does not exist
# City Number 318, college
# City Number 319, auki
# City Number 320, saint-francois
# City Number 321, qasigiannguit
# City Number 322, bonthe
# City Number 323, shetpe
# City Number 324, gornopravdinsk
# City Number 325, waddan
# City Number 326, vagur
# City Number 327, aripuana
# City Number 328, oswego
# City Number 329, muzhi
# City Number 330, trinidad
# City Number 331, kawalu
# City Number 332, ostrovskoye
# City Number 333, maracaju
# City Number 334, nome
# City Number 335, takoradi
# City Number 336, phan thiet
# HEY! palabuhanratu does not exist
# City Number 337, leshukonskoye
# City Number 338, ciudad bolivar
# City Number 339, portland
# City Number 340, cairns
# City Number 341, kavaratti
# City Number 342, magadi
# City Number 343, sisimiut
# City Number 344, flinders
# City Number 345, koungou
# City Number 346, torbay
# City Number 347, norman wells
# City Number 348, wangaratta
# City Number 349, dhidhdhoo
# City Number 350, tsuyama
# City Number 351, pumiao
# City Number 352, isangel
# City Number 353, montrose
# City Number 354, petropavlovsk-kamchatskiy
# City Number 355, cedar city
# City Number 356, tres lagoas
# HEY! saleaula does not exist
# City Number 357, libreville
# HEY! chagda does not exist
# City Number 358, shache
# City Number 359, naze
# City Number 360, kondinskoye
# City Number 361, burnie
# HEY! luceville does not exist
# City Number 362, cockburn town
# HEY! velestinon does not exist
# City Number 363, luanda
# City Number 364, san pedro
# City Number 365, krasnoarmeysk
# City Number 366, bexhill
# City Number 367, harnosand
# City Number 368, opava
# City Number 369, labuhan
# City Number 370, erenhot
# City Number 371, kendari
# City Number 372, zheleznodorozhnyy
# City Number 373, bullhead city
# City Number 374, ayacucho
# HEY! dolbeau does not exist
# City Number 375, beyneu
# City Number 376, atasu
# City Number 377, astana
# City Number 378, empalme
# City Number 379, hollins
# City Number 380, namatanai
# City Number 381, xuddur
# City Number 382, bandarbeyla
# City Number 383, zhigansk
# City Number 384, hualmay
# City Number 385, scarborough
# City Number 386, kropotkin
# City Number 387, ahipara
# City Number 388, jaque
# City Number 389, gualeguay
# HEY! burica does not exist
# City Number 390, port hardy
# City Number 391, kresttsy
# City Number 392, banda aceh
# City Number 393, talas
# City Number 394, corinth
# City Number 395, alakurtti
# City Number 396, marrakesh
# City Number 397, alyangula
# City Number 398, burla
# City Number 399, yulin
# City Number 400, nuuk
# City Number 401, betsiamites
# City Number 402, gra liyia
# City Number 403, merauke
# City Number 404, yumen
# HEY! kuche does not exist
# City Number 405, tigil
# City Number 406, sungurlare
# City Number 407, olenegorsk
# City Number 408, mathbaria
# City Number 409, thiruvananthapuram
# City Number 410, moose factory
# HEY! toliary does not exist
# City Number 411, huarmey
# City Number 412, lasa
# HEY! yunjinghong does not exist
# City Number 413, lakhimpur
# HEY! tabiauea does not exist
# City Number 414, langsa
# City Number 415, miura
# City Number 416, potiskum
# City Number 417, beloha
# City Number 418, roma
# City Number 419, shingu
# City Number 420, rawlins
# City Number 421, fenoarivo
# City Number 422, mackay
# City Number 423, hare bay
# City Number 424, nouadhibou
# City Number 425, abbeville
# City Number 426, gamba
# City Number 427, grenville
# City Number 428, ushumun
# City Number 429, magistralnyy
# City Number 430, bardiyah
# City Number 431, adrar
# City Number 432, boyolangu
# City Number 433, sharjah
# City Number 434, noumea
# City Number 435, dekar
# City Number 436, mana
# City Number 437, vulcan
# City Number 438, kismayo
# City Number 439, aykhal
# City Number 440, wuning
# City Number 441, honiara
# City Number 442, sur
# City Number 443, prince rupert
# City Number 444, thohoyandou
# City Number 445, zlotow
# City Number 446, uusikaupunki
# City Number 447, teguldet
# City Number 448, port lincoln
# City Number 449, walvis bay
# City Number 450, katra
# City Number 451, beian
# HEY! duz does not exist
# HEY! grand centre does not exist
# City Number 452, hofn
# City Number 453, mogadishu
# City Number 454, daru
# City Number 455, goundam
# City Number 456, qaqortoq
# City Number 457, heishan
# City Number 458, south valley
# City Number 459, bitung
# City Number 460, ilulissat
# City Number 461, scottsbluff
# City Number 462, komsomolskiy
# City Number 463, hay river
# City Number 464, kulob
# City Number 465, somerset
# City Number 466, hidalgotitlan
# City Number 467, port macquarie
# City Number 468, salamiyah
# City Number 469, havre-saint-pierre
# City Number 470, saint-augustin
# City Number 471, marienburg
# City Number 472, bilibino
# City Number 473, almirante
# City Number 474, bumba
# City Number 475, te anau
# City Number 476, belokurikha
# City Number 477, viedma
# City Number 478, qostanay
# City Number 479, porto walter
# City Number 480, alta floresta
# City Number 481, kalur kot
# City Number 482, alenquer
# HEY! meyungs does not exist
# City Number 483, huron
# City Number 484, dergachi
# City Number 485, tibati
# City Number 486, vostok
# City Number 487, ketchikan
# City Number 488, vilyuysk
# City Number 489, oussouye
# City Number 490, rumford
# City Number 491, warri
# City Number 492, faya
# City Number 493, cap malheureux
# City Number 494, bourail
# City Number 495, jaguaribe
# City Number 496, faaborg
# City Number 497, penarroya-pueblonuevo
# City Number 498, buribay
# City Number 499, whitehorse
# City Number 500, brae
# City Number 501, sembe
# City Number 502, limon
# HEY! afmadu does not exist
# City Number 503, kathu
# City Number 504, constitucion
# City Number 505, sao joao da barra
# City Number 506, storsteinnes
# City Number 507, kjollefjord
# City Number 508, nioro
# City Number 509, uige
# City Number 510, pekalongan
# HEY! ngukurr does not exist
# City Number 511, gambela
# HEY! kytlym does not exist
# City Number 512, krasnoselkup
# City Number 513, umm kaddadah
# HEY! sumbawa does not exist
# City Number 514, kaeo
# City Number 515, ancud
# City Number 516, olafsvik
# City Number 517, birin
# City Number 518, rio gallegos
# City Number 519, olinda
# City Number 520, pendleton
# City Number 521, kita
# City Number 522, sakakah
# HEY! port-de-paix does not exist
# City Number 523, comodoro rivadavia
# City Number 524, hirado
# City Number 525, tromso
# City Number 526, tayshet
# City Number 527, yenagoa
# City Number 528, kuliyapitiya
# HEY! ozgon does not exist
# City Number 529, hervey bay
# City Number 530, solnechnyy
# City Number 531, tiksi
# City Number 532, tilichiki
# City Number 533, kalcheva
# City Number 534, svetlyy
# City Number 535, cabedelo
# City Number 536, loharu
# City Number 537, houma
# City Number 538, bosaso
# City Number 539, tazovskiy
# City Number 540, sibolga
# City Number 541, sinop
# City Number 542, halifax
# City Number 543, chapais
# City Number 544, codrington
# City Number 545, mizdah
# City Number 546, nova borova
# City Number 547, campos belos
# City Number 548, wigston
# City Number 549, ossora
# City Number 550, yakeshi
# City Number 551, vicuna
# City Number 552, itarema
# City Number 553, sukhobezvodnoye
# City Number 554, mayo
# City Number 555, jurado
# City Number 556, gimli
# City Number 557, kirakira
# HEY! kazalinsk does not exist
# City Number 558, kudahuvadhoo
# City Number 559, mbandaka
# City Number 560, olga
# City Number 561, vila velha
# City Number 562, nelson bay
# City Number 563, leningradskiy
# City Number 564, aksarka
# City Number 565, los alamos
# City Number 566, teya
# City Number 567, esna

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
